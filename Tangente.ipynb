# %%
from pylab import *

# %%
x = linspace(-pi,2*pi,100)
y = tan(x)
plot(x,y)
ylim([-2,2])
grid()
show()

# %%
y[:-1][diff(y) < 0] = nan
plot(x,y)
ylim([-2,2])
grid()
show()

# %%
y
# Out:
# array([ 1.22464680e-16,  9.54884223e-02,  1.92734202e-01,  2.93626493e-01,
#         4.00339609e-01,  5.15535831e-01,  6.42660977e-01,  7.86408692e-01,
#         9.53498074e-01,  1.15406152e+00,  1.40430351e+00,  1.73205081e+00,
#         2.18969456e+00,  2.88931025e+00,  4.12205614e+00,  6.95515277e+00,
#                    nan, -2.09925835e+01, -6.95515277e+00, -4.12205614e+00,
#        -2.88931025e+00, -2.18969456e+00, -1.73205081e+00, -1.40430351e+00,
#        -1.15406152e+00, -9.53498074e-01, -7.86408692e-01, -6.42660977e-01,
#        -5.15535831e-01, -4.00339609e-01, -2.93626493e-01, -1.92734202e-01,
#        -9.54884223e-02,  0.00000000e+00,  9.54884223e-02,  1.92734202e-01,
#         2.93626493e-01,  4.00339609e-01,  5.15535831e-01,  6.42660977e-01,
#         7.86408692e-01,  9.53498074e-01,  1.15406152e+00,  1.40430351e+00,
#         1.73205081e+00,  2.18969456e+00,  2.88931025e+00,  4.12205614e+00,
# ...

# %%
736203*3 - 2390000
# Out:
# -181391
